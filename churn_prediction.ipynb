# %% [markdown]
# <a href="https://colab.research.google.com/github/SahanashreeTalagade/Banking-Churn-ML-Pipeline/blob/main/churn_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Domain Analysis:
